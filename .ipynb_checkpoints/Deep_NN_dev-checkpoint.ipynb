# %% [markdown]
# # One-Layer Neural Network from scratch

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
import time
import cv2
import warnings
warnings.filterwarnings('ignore')

from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean

np.random.seed(1) # set a seed so that the results are consistent

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ## Load Datasets

# %%
# Load the data from h5 file
def load_dataset():
#     train_dataset = h5py.File('/content/gdrive/My Drive/CoderSchool-FTMLE/data/datasets/catdog/catsvsdogs-train.h5', "r")
    train_dataset = h5py.File('./data/catsvsdogs-train.h5', "r")
    train_set_x_orig = np.array(train_dataset["images"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["labels"][:]) # your train set labels
    
#     test_dataset = h5py.File('/content/gdrive/My Drive/CoderSchool-FTMLE/data/datasets/catdog/catsvsdogs-test.h5', "r")
    test_dataset = h5py.File('./data/catsvsdogs-test.h5', "r")
    test_set_x_orig = np.array(test_dataset["images"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["labels"][:]) # your test set labels
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig

# %%
train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig = load_dataset()

# %% [markdown]
# ### Convert BGR to RGB Images
# Because we use opencv to load our dataset that makes all images in BGR color mode. Hence, we need to convert the color mode back to RGB.

# %%
def convert_bgr_rgb(dataset):
  rgb_dataset = np.empty([len(dataset), dataset[1].shape[0], dataset[1].shape[1], dataset[1].shape[2]], dtype=np.int16)
  
  print(rgb_dataset.shape)
                          
  for i in range(0, len(dataset)):
    image = dataset[i]
    rgb_dataset[i] = image[:,:,::-1] # revert the color modes
  
  return rgb_dataset

train_set_x_rgb = convert_bgr_rgb(train_set_x_orig)
test_set_x_rgb = convert_bgr_rgb(test_set_x_orig)
# Out:
# (5000, 128, 128, 3)
# (500, 128, 128, 3)

# %%
print("Train dataset shape:", train_set_x_rgb.shape)
print("Test dataset shape:", test_set_x_rgb.shape)

index_train = np.random.randint(0,len(train_set_x_rgb)) 
index_test = np.random.randint(0,len(test_set_x_rgb)) 

fig, axes = plt.subplots(nrows=1, ncols=2)

ax = axes.ravel()

ax[0].imshow(train_set_x_rgb[index_train], cmap='gray')
ax[0].set_title("Train image")

ax[1].imshow(test_set_x_rgb[index_test], cmap='gray')
ax[1].set_title("Test image")

plt.show()
# Out:
# Train dataset shape: (5000, 128, 128, 3)
# Test dataset shape: (500, 128, 128, 3)

# %% [markdown]
# ### EDA

# %%
# Some some random images and their labels
plt.subplots(figsize = (8,8))
plt.subplot(221)
index_1 = np.random.randint(0,len(train_set_x_rgb)) 
plt.imshow(train_set_x_rgb[index_1])
plt.title("y = " + str(train_set_y_orig[index_1]))

plt.subplot(222)
index_2 = np.random.randint(0,len(train_set_x_rgb))
plt.imshow(train_set_x_rgb[index_2])
plt.title("y = " + str(train_set_y_orig[index_2]))

plt.subplot(223)
index_3 = np.random.randint(0,len(train_set_x_rgb))
plt.imshow(train_set_x_rgb[index_3])
plt.title("y = " + str(train_set_y_orig[index_3]))

plt.subplot(224)
index_4 = np.random.randint(0,len(train_set_x_rgb))
plt.imshow(train_set_x_rgb[index_4])
plt.title("y = " + str(train_set_y_orig[index_4]))

plt.show()

# %%
# Visualization the train set labels
unique, counts = np.unique(train_set_y_orig, return_counts = True)
dict1 = dict(zip(unique, counts))
plt.figure(figsize=(6,6))
plt.pie(x = counts, labels = ['dog: %s' % counts[0],'cat: %s' % counts[1]], autopct = '%1.1f%%', startangle=90, textprops={'fontsize': 14})
plt.title('Train set: Cat vs. Dog', fontdict={'fontsize': 14})
plt.show()

# %% [markdown]
# ## Implement neuron networks model from scratch

# %% [markdown]
# ## Building model
#
# In this notebook, you will implement all the functions required to build a deep neural network.
#
# ![](https://i.imgur.com/ivhZhmx.png)
#
# **Notation**:
# - Superscript $[l]$ denotes a quantity associated with the $l^{th}$ layer.
#     - Example: $a^{[L]}$ is the $L^{th}$ layer activation. $W^{[L]}$ and $b^{[L]}$ are the $L^{th}$ layer parameters.
# - Superscript $(i)$ denotes a quantity associated with the $i^{th}$ example.
#     - Example: $x^{(i)}$ is the $i^{th}$ training example.
# - Lowerscript $i$ denotes the $i^{th}$ entry of a vector.
#     - Example: $a^{[l]}_i$ denotes the $i^{th}$ entry of the $l^{th}$ layer's activations).
#
# The initialization for a deeper L-layer neural network is more complicated because there are many more weight matrices and bias vectors. When completing the `initialize_params`, you should make sure that your dimensions match between each layer. Given $n^{[l]}$ is the number of units in layer $l$. Thus for example if the size of our input $X$ is $(12288, 209)$ (with $m=209$ examples) then:
#
# | |**Shape of W**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; |**Shape of b**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|**Activation**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|**Shape of Activation**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|
# |:-|:-|:-|:-|:-|
# |**Layer 1**|$(n^{[1]},12288)$|$(n^{[1]},1)$|$Z^{[1]} = W^{[1]}  X + b^{[1]} $|$(n^{[1]},209)$|
# | **Layer 2**|$(n^{[2]}, n^{[1]})$|$(n^{[2]},1)$|$Z^{[2]} = W^{[2]} A^{[1]} + b^{[2]}$|$(n^{[2]}, 209)$|
# |$\vdots$| $\vdots$ | $\vdots$|$\vdots$|$\vdots$|
# |**Layer L-1** | $(n^{[L-1]}, n^{[L-2]})$ | $(n^{[L-1]}, 1)$ | $Z^{[L-1]} =  W^{[L-1]} A^{[L-2]} + b^{[L-1]}$ | $(n^{[L-1]}, 209)$|
# |**Layer L** | $(n^{[L]}, n^{[L-1]})$ | $(n^{[L]}, 1)$|  $Z^{[L]} =  W^{[L]} A^{[L-1]} + b^{[L]}$|$(n^{[L]}, 209)$ |
#
# Remember that when we compute $W X + b$ in python, it carries out broadcasting. For example, if:
#
# $$ W = \begin{bmatrix}
#     j  & k  & l\\
#     m  & n & o \\
#     p  & q & r
# \end{bmatrix}\;\;\; X = \begin{bmatrix}
#     a  & b  & c\\
#     d  & e & f \\
#     g  & h & i
# \end{bmatrix} \;\;\; b =\begin{bmatrix}
#     s  \\
#     t  \\
#     u
# \end{bmatrix}$$
#
# Then $WX + b$ will be:
#
# $$ WX + b = \begin{bmatrix}
#     (ja + kd + lg) + s  & (jb + ke + lh) + s  & (jc + kf + li)+ s\\
#     (ma + nd + og) + t & (mb + ne + oh) + t & (mc + nf + oi) + t\\
#     (pa + qd + rg) + u & (pb + qe + rh) + u & (pc + qf + ri)+ u
# \end{bmatrix}$$

# %% [markdown]
# ### sigmoid, relu, layer_sizes

# %%
def sigmoid(Z):
  return 1/(1 + np.exp(-Z))

# %%
def relu(Z):
  return np.maximum(0, Z)

# %%
def relu_backward(Z):
  temp = np.ones(Z.shape)
  temp[Z<0] = 0
  return temp

# %%
def layer_sizes(X, Y, hidden_layers):
  layer_dims = np.array(hidden_layers, copy = True)
  
  layer_dims = np.insert(layer_dims, 0, X.shape[1])
  layer_dims = np.append(layer_dims, Y.shape[0])
  
  return layer_dims

# %% [markdown]
# ### initialize

# %%
def initialize_params(layer_dims):
  np.random.seed(1)
  
  params = {}
  L = len(layer_dims)
  n_x = layer_dims[0]
    
  for i in range(1, L):
    n_h = layer_dims[i]
    n_x = layer_dims[i-1]
    params['W' + str(i)] = np.random.randn(n_h, n_x) / np.sqrt(n_x)
    params['b' + str(i)] = np.zeros((n_h, 1))
    
    # we use assert to double check the array shape
    assert(params['W' + str(i)].shape == (n_h, n_x))
    assert(params['b' + str(i)].shape == (n_h, 1))
  
  return params

# %% [markdown]
# ### forward_propagation

# %%
def forward_propagation(X, params):    
  caches = {}
  A_prev = X.T
  L = len(params) // 2
  
  for i in range(1, L):
    bi = params['b' + str(i)]
    Wi = params['W' + str(i)]
    Zi = np.dot(Wi, A_prev) + bi
    Ai = relu(Zi)
    
    caches['A' + str(i)] = Ai
    caches['Z' + str(i)] = Zi
    
    A_prev = Ai
  
  Z_last = np.dot(params['W' + str(L)], caches['A' + str(L-1)]) + params['b' + str(L)]
  A_last = sigmoid(Z_last)
    
  caches['A' + str(L)] = A_last
  caches['Z' + str(L)] = Z_last
  
  return A_last, caches

# %% [markdown]
# ### compute cost J

# %%
def compute_cross_entropy_cost(Y, A_last):
  m = Y.shape[1]
  
  loss = np.multiply(Y, np.log(A_last)) + np.multiply(1 - Y, np.log(1 - A_last))
  J = (-1/m) * np.sum(loss)
  J = np.squeeze(J) # np.squeeze(24) => 24
  
  return J

# %% [markdown]
# ### backward_propagation

# %%
def backward_propagation(X, Y, params, caches):
  m = X.shape[0]
  L = len(params) // 2
  grads = {}
    
  A_last_prev = caches['A' + str(L-1)]
  A_last = caches['A' + str(L)]
  
  dZ_last = A_last - Y
  dW_last = (1/m) * np.dot(dZ_last, A_last_prev.T)
  db_last = (1/m) * np.sum(dZ_last, axis=1, keepdims=True)
  
  grads['dZ' + str(L)] = dZ_last
  grads['dW' + str(L)] = dW_last
  grads['db' + str(L)] = db_last
  
  for i in range(L-1, 0, -1): 
    Wi = params['W' + str(i+1)]
    bi = params['b' + str(i)]
    Ai_prev = caches['A' + str(i-1)] if (i) > 1 else X.T
    Zi = caches['Z' + str(i)]
    
    dZi = np.multiply(np.dot(Wi.T, grads['dZ' + str(i+1)]), relu_backward(Zi))
    dWi = (1/m) * np.dot(dZi, Ai_prev.T)
    dbi = (1/m) * np.sum(dZi, axis=1, keepdims=True)
    
    grads['dZ' + str(i)] = dZi
    grads['dW' + str(i)] = dWi
    grads['db' + str(i)] = dbi
  
  return grads

# %% [markdown]
# ### update_params

# %%
def update_params(params, grads, learning_rate):
  
  L = len(params) // 2
  
  for i in range(1, L+1):
    Wi = params['W' + str(i)]
    bi = params['b' + str(i)]
    dWi = grads['dW' + str(i)]
    dbi = grads['db' + str(i)]
  
    Wi = Wi - learning_rate * dWi
    bi = bi - learning_rate * dbi
  
    params['W' + str(i)] = Wi
    params['b' + str(i)] = bi
    
  return params

# %% [markdown]
# ## Build our neural network in `dnn_model()`

# %% [markdown]
# ### dnn_model

# %%
def dnn_model(X, Y, hidden_layers, iterations, learning_rate, batch_size):
  
  costs = []
  test_errors = []
  reports = {}
  
  layer_dims = layer_sizes(X, Y, hidden_layers)
  
  print(layer_dims)
  
  parameters = initialize_params(layer_dims)
  
  for i in range(iterations):
    # generate train batch from batch_size
    batch = np.random.randint(0, X.shape[0], batch_size)
    X_batch_train = X[batch,:]
    y_batch_train = Y[0, batch].reshape(1, -1)
    
    # forward_probagation
    A_last, caches = forward_propagation(X_batch_train, parameters)
    
    # Compute cost
    J = compute_cross_entropy_cost(y_batch_train, A_last)
    
    # backward_probagation
    grads = backward_propagation(X_batch_train, y_batch_train, parameters, caches)
    
    # Update parameters
    parameters = update_params(parameters, grads, learning_rate)
    
    if i%100 == 0:
      # Update progress
      costs.append(J)
      predictions, A2_test = predict(X_test, parameters)
      val_predictions, train_A2_test = predict(X_validation, parameters)
      test_acc_score = accuracy_score(y_test[0], predictions[0])
      test_error = 1 - test_acc_score
      test_errors.append(test_error)
      print("Iteration %i, cost %f, test error %f" % (i, J, test_error))
      print("Validation set accuracy score:", accuracy_score(y_validation[0], val_predictions[0]))
      print("Test set accuracy score:", test_acc_score)
  
  reports['costs'] = costs
  reports['test_errors'] = test_errors
  
  return parameters, reports

# %% [markdown]
# ### predict

# %%
def predict(X, params):
  A_last, cache = forward_propagation(X, params)
  predictions = A_last > 0.5
  return predictions, A_last

# %% [markdown]
# ### main

# %%
# Convert X to 2D array
X_train = train_set_x_rgb.flatten().reshape((len(train_set_x_rgb),-1)) / 255
X_train, X_validation, y_train, y_validation = train_test_split(X_train, train_set_y_orig, test_size=0.25, random_state=42)
X_test = test_set_x_rgb.flatten().reshape((len(test_set_x_rgb),-1)) / 255
# X_train = train_set_x_orig.flatten().reshape((len(train_set_x_orig),-1)) / 255
# X_test = test_set_x_orig.flatten().reshape((len(test_set_x_orig),-1)) / 255

# Convert y to 1D array
y_train = y_train.reshape(1, -1)
y_validation = y_validation.reshape(1, -1)
y_test = test_set_y_orig.reshape(1, -1)

# %%
X_train.shape, y_train.shape, X_validation.shape, y_validation.shape, X_test.shape, y_test.shape
# Out:
# ((3750, 49152), (1, 3750), (1250, 49152), (1, 1250), (500, 49152), (1, 500))

# %%
nn = len(X_train_scaled) / (10 * (5 + 1))
print(nn)
# Out:
# 8.316666666666666

# %%
hidden_layers = [30, 30, 30, 30, 30]
iterations = 2000
learning_rate = 3e-3
batch_size = 64

t0 = time.time()
parameters, reports = dnn_model(X_train, y_train, hidden_layers, iterations, learning_rate, batch_size)

predictions, A_last = predict(X_test_scaled, parameters)
t1 = time.time()
print("run time:", t1 - t0)
# Out:
# [49152    30    30    30    30    30     1]
# Iteration 0, cost 0.698371, test error 0.490000
# Validation set accuracy score: 0.496
# Test set accuracy score: 0.51
# Iteration 100, cost 0.691098, test error 0.486000
# Validation set accuracy score: 0.496
# Test set accuracy score: 0.514
# Iteration 200, cost 0.681454, test error 0.484000
# Validation set accuracy score: 0.5016
# Test set accuracy score: 0.516
# Iteration 300, cost 0.678973, test error 0.462000
# Validation set accuracy score: 0.5328
# Test set accuracy score: 0.538
# Iteration 400, cost 0.678760, test error 0.396000
# Validation set accuracy score: 0.5864
# Test set accuracy score: 0.604
# Iteration 500, cost 0.648964, test error 0.456000
# Validation set accuracy score: 0.5408
# Test set accuracy score: 0.544
# Iteration 600, cost 0.662748, test error 0.392000
# Validation set accuracy score: 0.6072
# Test set accuracy score: 0.608
# Iteration 700, cost 0.676095, test error 0.382000
# Validation set accuracy score: 0.6112
# Test set accuracy score: 0.618
# Iteration 800, cost 0.636720, test error 0.408000
# Validation set accuracy score: 0.5784
# Test set accuracy score: 0.592
# Iteration 900, cost 0.682411, test error 0.390000
# Validation set accuracy score: 0.6168
# Test set accuracy score: 0.61
# Iteration 1000, cost 0.647414, test error 0.440000
# Validation set accuracy score: 0.5792
# Test set accuracy score: 0.56
# Iteration 1100, cost 0.673431, test error 0.372000
# Validation set accuracy score: 0.6184
# Test set accuracy score: 0.628
# Iteration 1200, cost 0.635257, test error 0.446000
# Validation set accuracy score: 0.5696
# Test set accuracy score: 0.554
# Iteration 1300, cost 0.626271, test error 0.398000
# Validation set accuracy score: 0.6
# Test set accuracy score: 0.602
# Iteration 1400, cost 0.743123, test error 0.412000
# Validation set accuracy score: 0.5728
# Test set accuracy score: 0.588
# Iteration 1500, cost 0.616752, test error 0.368000
# Validation set accuracy score: 0.6336
# Test set accuracy score: 0.632
# Iteration 1600, cost 0.658092, test error 0.418000
# Validation set accuracy score: 0.5808
# Test set accuracy score: 0.582
# Iteration 1700, cost 0.609966, test error 0.362000
# Validation set accuracy score: 0.6056
# Test set accuracy score: 0.638
# Iteration 1800, cost 0.592884, test error 0.376000
# Validation set accuracy score: 0.6104
# Test set accuracy score: 0.624
# Iteration 1900, cost 0.570955, test error 0.378000
# Validation set accuracy score: 0.6248
# Test set accuracy score: 0.622
# run time: 121.7976586818695

# %%
layer_dims = layer_sizes(X_train, y_train, hidden_layers)
print('layer dims:', layer_dims)
print("iterations: {} -- learning_rate: {}".format(iterations, learning_rate))

# plot the cost
fig, ax = plt.subplots(figsize=[12, 6])
plt.plot(reports['costs'])
plt.plot(reports['test_errors'], c='r')
plt.ylabel('cost')
plt.xlabel('iterations (per hundreds)')
plt.title('Learning rate=' + str(learning_rate) )
plt.show()

# show accuracy scores
predictions, A_last = predict(X_train, parameters)
print("Accuracy Score - Training set: %f" % accuracy_score(y_train[0], predictions[0]))
print("Confusion Matrix:")
print(confusion_matrix(y_train[0], predictions[0]))
print('\n')
predictions, A_last = predict(X_test, parameters)
print("Accuracy Score - Test set: %f" % accuracy_score(y_test[0], predictions[0]))
print("Confusion Matrix:")
print(confusion_matrix(y_test[0], predictions[0]))
# Out:
# layer dims: [49152    30    30    30    30    30     1]
# iterations: 2000 -- learning_rate: 0.003
# Accuracy Score - Training set: 0.692800
# Confusion Matrix:
# [[1115  801]
#  [ 351 1483]]
#
#
# Accuracy Score - Test set: 0.624000
# Confusion Matrix:
# [[124 131]
#  [ 57 188]]

# %% [markdown]
# ### TODO: Save our model

# %% [markdown]
# ### Print Mislabeled Images

# %%
def print_mislabeled_images(X, y, p):
    a = p + y
    mislabeled_indices = np.asarray(np.where(a == 1))
    plt.rcParams['figure.figsize'] = (40.0, 40.0) # set default size of plots
    num_images = len(mislabeled_indices[0])
    print('Total mislabels:', num_images)
    
    for i in range(num_images):
        index = mislabeled_indices[1][i]
        
        plt.subplot(2, num_images, i + 1)
        plt.imshow(X[index, :].reshape(128,128,3), interpolation='nearest')
        plt.axis('off')
        plt.title("Prediction: " + str(p[0,index]) + " \n Class: " + str(y[0,index]))

# %%
mislabeled = get_mislabeled_images(X_test, y_test, predictions)
print_mislabeled_images(mislabeled)
# Out:
# Total mislabeled images: 188
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-267-e5a1cddcdb55> in <module>
#       1 mislabeled = get_mislabeled_images(X_test, y_test, predictions)
# ----> 2 print_mislabeled_images(mislabeled)
#
# <ipython-input-266-d0ebafe49764> in print_mislabeled_images(mislabeled_indices)
#      14
#      15       plt.subplot(2, num_images, i + 1)
# ---> 16       plt.imshow(X[index, :].reshape(128,128,3), interpolation='nearest')
#      17       plt.axis('off')
#      18       plt.title("Prediction: " + str(int(p[0,index])) + " \n Class: " + str(y[0,index]))
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## Model from sklearn

# %%
# Create Logistics Regression model from X and y
lg = LogisticRegression()
lg.fit(X_train, y_train[0])

# Show metrics
print("Accuracy Score: %f" % accuracy_score(y_test[0], lg.predict(X_test)))
print("Confusion Matrix:")
print(confusion_matrix(y_test[0], lg.predict(X_test)))
# Out:
# Accuracy Score: 0.576000
# Confusion Matrix:
# [[130 125]
#  [ 87 158]]
